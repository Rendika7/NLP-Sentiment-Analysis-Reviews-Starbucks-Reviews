# %% [markdown]
# > # Load Model
# ---

# %%
import keras
import tensorflow as tf
import os

# %%
# Check if the file exists
model_file = "/content/drive/MyDrive/Colab Notebooks/5. Project [Data Bridge]/NLP for Starbucks Reviews Dataset/model.keras"
if not os.path.exists(model_file):
    raise FileNotFoundError(f"Model file '{model_file}' not found.")


from tensorflow.keras.models import load_model

# Load the model
loaded_model = load_model(model_file)

# Get the model summary
loaded_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  text_vectorization (TextVe  (None, 118)               0
#  ctorization)
#
#  embedding_1 (Embedding)     (None, 118, 128)          6016
#
#  bidirectional (Bidirection  (None, 118, 64)           41216
#  al)
#
#  dropout (Dropout)           (None, 118, 64)           0
#
#  bidirectional_1 (Bidirecti  (None, 32)                10368
#  onal)
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 3)                 99
#
# ...
# Total params: 57699 (225.39 KB)
# Trainable params: 57699 (225.39 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Data Used for Predict :
#
# [kanchana1990/starbucks-nyc-1000-reviews [Kaggle]](https://www.kaggle.com/datasets/kanchana1990/starbucks-nyc-1000-reviews)

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/5. Project [Data Bridge]/NLP for Starbucks Reviews Dataset/Data/Data Used for Prediction.csv")

# %%
df.isnull().sum()
# Out:
# publishedDate    0
# title            0
# text             0
# rating           0
# dtype: int64

# %%
import numpy as np

# Make predictions using the loaded model
np.argmax(loaded_model.predict(df["text"]), axis=-1)
# Out:
# 25/25 [==============================] - 3s 38ms/step
# array([2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        1, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 1, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
#        2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2,
# ...
